# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv (r"C:\Users\fabi_\OneDrive\Estudos e Cursos\Data analytics\Ironhack.Labs\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv")

# %%
file
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %% [markdown]
# # Show the dataframe shape

# %%
file.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
file.shape
# Out:
# (10910, 26)

# %%
file.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
file.nunique()
# Out:
# Unnamed: 0                       10910
# Customer                          9134
# State                                5
# Customer Lifetime Value           8041
# Response                             2
# Coverage                             3
# Education                            5
# Effective To Date                   59
# EmploymentStatus                     5
# Gender                               2
# Income                            5694
# Location Code                        3
# Marital Status                       3
# Monthly Premium Auto               202
# Months Since Last Claim             36
# Months Since Policy Inception      100
# Number of Open Complaints            6
# Number of Policies                   9
# Policy Type                          3
# Policy                               9
# Renew Offer Type                     4
# Sales Channel                        4
# Total Claim Amount                5106
# Vehicle Class                        6
# ...

# %%
file.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
file.tail()
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# ...

# %% [markdown]
# # Standardize header names

# %%
file.columns
cols = []
for i in range (len(file.columns)): 
    cols.append(file.columns[i].lower().replace(' ', '_'))
file.columns = cols
file = file.rename (columns = {'employmentstatus' : 'employment_status'})
file
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employment_status gender  ...  \
# ...

# %% [markdown]
# # Numerical and Categorigal columns

# %%
categ_cols = file.select_dtypes(exclude=['number']).columns.tolist()
categ_cols
# Out:
# ['customer',
#  'state',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employment_status',
#  'gender',
#  'location_code',
#  'marital_status',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
types_of_unique_values = ['customer',
 'state',
 'response',
 'coverage',
 'education',
 'effective_to_date',
 'employment_status',
 'gender',
 'location_code',
 'marital_status',
 'policy_type',
 'policy',
 'renew_offer_type',
 'sales_channel',
 'vehicle_class',
 'vehicle_size',
 'vehicle_type']
for column in types_of_unique_values:
    unique_values = file[column].unique()
    print(f"Unique values for {column}:")
    print(unique_values)
    print()
# Out:
# Unique values for customer:
# ['DK49336' 'KX64629' 'LZ68649' ... 'KX53892' 'TL39050' 'WA60547']
#
# Unique values for state:
# ['Arizona' 'California' 'Washington' 'Oregon' nan 'Nevada']
#
# Unique values for response:
# ['No' 'Yes' nan]
#
# Unique values for coverage:
# ['Basic' 'Extended' 'Premium']
#
# Unique values for education:
# ['College' 'Bachelor' 'High School or Below' 'Doctor' 'Master']
#
# Unique values for effective_to_date:
# ['2/18/11' '1/18/11' '2/10/11' '1/11/11' '1/17/11' '2/14/11' '2/24/11'
#  '1/19/11' '1/4/11' '1/2/11' '2/7/11' '1/31/11' '1/26/11' '2/28/11'
#  '1/16/11' '2/26/11' '2/23/11' '1/15/11' '2/2/11' '2/15/11' '1/24/11'
#  '2/21/11' '2/22/11' '1/7/11' '1/28/11' '2/8/11' '2/12/11' '2/20/11'
#  '1/5/11' '2/19/11' '1/3/11' '2/3/11' '1/22/11' '1/23/11' '2/5/11'
#  '2/13/11' '1/25/11' '2/16/11' '2/1/11' '1/27/11' '1/12/11' '1/20/11'
#  '2/6/11' '2/11/11' '1/21/11' '1/29/11' '1/9/11' '2/9/11' '2/27/11'
# ...

# %%
num_cols = file.select_dtypes(include=['number']).columns.tolist()
num_cols
# Out:
# ['unnamed:_0',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'total_claim_amount']

# %%
types_of_unique_values = ['unnamed:_0',
 'customer_lifetime_value',
 'income',
 'monthly_premium_auto',
 'months_since_last_claim',
 'months_since_policy_inception',
 'number_of_open_complaints',
 'number_of_policies',
 'total_claim_amount']
for column in types_of_unique_values:
    unique_values = file[column].unique()
    print(f"Unique values for {column}:")
    print(unique_values)
    print()
# Out:
# Unique values for unnamed:_0:
# [    0     1     2 ... 10907 10908 10909]
#
# Unique values for customer_lifetime_value:
# [ 4809.21696   2228.525238 14947.9173   ...  5259.444853 23893.3041
#  11971.97765 ]
#
# Unique values for income:
# [48029     0 22139 ... 61146 39837 64195]
#
# Unique values for monthly_premium_auto:
# [ 61  64 100  97 117  63 154  85 127  62  99  69 116 114  66  73  94 104
#  189  74 121 110 111  72 115 159 101  65  82  71 126  68 199  96  67 125
#  249 105  92  78  77  79 223 242  70 102 109 107 119 194 113 106 247  80
#   86  81  83 122 253 196 132 139  84 130  93 103 112 222 118  88 182 283
#   90 128  89 235 190  76  87 133 153 129  98 148 123  91 211 131 108 187
#  214 181 173 252  95 124 137 145 188 143 198 138 245 195 186 170 136 161
#  157 141 205 271 192 142 140 134 240 185 244 210 184 202 296 213 273 219
#  135 169 155 225 266 215 197 256 212 158 180 166 168 183 162 191 179 150
# ...

# %% [markdown]
# # Check and deal with NaN values

# %%
file.isna()
# Out:
#        unnamed:_0  customer  state  customer_lifetime_value  response  \
# 0           False     False  False                    False     False
# 1           False     False  False                    False     False
# 2           False     False  False                    False     False
# 3           False     False  False                    False     False
# 4           False     False  False                    False     False
# ...           ...       ...    ...                      ...       ...
# 10905       False     False  False                    False     False
# 10906       False     False  False                    False     False
# 10907       False     False  False                    False     False
# 10908       False     False  False                    False     False
# 10909       False     False   True                    False      True
#
#        coverage  education  effective_to_date  employment_status  gender  ...  \
# ...

# %%
condition = file.isna().any(axis = 1)
file[condition]
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 4               4  QA50777      Oregon              9025.067525       No
# 5               5  HO81102         NaN              4745.181764      NaN
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10900       10900  VN73653      Oregon              6423.739052       No
# 10901       10901  RY92254  Washington              4547.892543       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage             education effective_to_date employment_status  \
# ...

# %%
# there are NaN values in 6367 rows, around half the number of rows

# %%
file.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employment_status                   0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
# most NaN are in vehicle_type, they could all be type A, or there could be another type

# %%
(file.isna().sum() / len(file))*100
# Out:
# unnamed:_0                        0.000000
# customer                          0.000000
# state                             5.783685
# customer_lifetime_value           0.000000
# response                          5.783685
# coverage                          0.000000
# education                         0.000000
# effective_to_date                 0.000000
# employment_status                 0.000000
# gender                            0.000000
# income                            0.000000
# location_code                     0.000000
# marital_status                    0.000000
# monthly_premium_auto              0.000000
# months_since_last_claim           5.802016
# months_since_policy_inception     0.000000
# number_of_open_complaints         5.802016
# number_of_policies                0.000000
# policy_type                       0.000000
# policy                            0.000000
# renew_offer_type                  0.000000
# sales_channel                     0.000000
# ...

# %%
# Decided not to drop the NaN because for vehicle_type that's 50% of the values

# %% [markdown]
# # Datetime format

# %%
# change dtype of effective_to_date to datetime

# %%
file['effective_to_date'] = pd.to_datetime(file['effective_to_date'])
file['effective_to_date']
# Out:
# C:\Users\fabi_\AppData\Local\Temp\ipykernel_9312\168365728.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   file['effective_to_date'] = pd.to_datetime(file['effective_to_date'])
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective_to_date, Length: 10910, dtype: datetime64[ns]

# %%
# Extract the months from the dataset and store in a separate column.

# %%
file['month'] = file['effective_to_date'].dt.month
file
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employment_status gender  ...  \
# ...

# %%
#Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
condition = file['month'] < 4
q1 = file[condition]
q1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employment_status gender  ...  \
# ...

# %% [markdown]
# # BONUS

# %% [markdown]
# Put all the previously mentioned data transformations into a function.

# %%
# Load the data
import pandas as pd
file_path = []
data = pd.read_csv(file_path)


def clean_data(df):
    # Show the dataframe shape
    df.shape
    df.dtypes
    df.columns
    df.nunique

    # Standardize header names
    df.columns = df.columns.str.lower().str.replace(' ', '_')

    
    # Which columns are numerical?
    numerical_columns = df.select_dtypes(include=['number']).columns.tolist()
    numerical_columns
    
    types_of_unique_values = [numerical_columns]
    for column in types_of_unique_values:
        unique_values = df[column].unique()
        print(f"Unique values for {column}:")
        print(unique_values)
        print()
   

    # Which columns are categorical?
    categorical_columns = df.select_dtypes(exclude=['number']).columns.tolist()
    categorical_columns
    
    types_of_unique_values = [categorical_columns]
    for column in types_of_unique_values:
        unique_values = df[column].unique()
        print(f"Unique values for {column}:")
        print(unique_values)
        print()
    

    # Check and deal with NaN values
    df.isna()
    condition = file.isna().any(axis = 1)
    file[condition]
    df.isna().sum()
    (file.isna().sum() / len(file))*100
            
    # Fill NaN values if necessary
    # df['column_name'].fillna(value, inplace=True)

    
    # Datetime format  
    df['column_name'] = pd.to_datetime(df['column_name'])
    #Extract the months from the dataset and store in a separate column
    df['month'] = pd.to_datetime(df['column_name']).dt.month

    # Filter the data to show only the information for the first quarter (January, February, and March)
    condition = file['month'] < 4
    q1 = file[condition]
    q1
    
    # Return the cleaned DataFrame
    return df
