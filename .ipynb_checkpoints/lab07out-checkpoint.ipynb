# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
mkt = pd.read_csv(r"C:\Users\pedro\Desktop\Ironhack\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv")
mkt
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#Show the dataframe shape.

mkt.shape
# Out:
# (10910, 26)

# %%
#Standardize header names.

cols = []
for i in range(len(mkt.columns)):
    cols.append(mkt.columns[i].lower().replace(' ','_'))

mkt.columns = cols
mkt
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
'''
numerical columns: customer_lifetime_value, income, monthly_premium_auto, months_since_last_claim, 
months_since_policy_inception, number_of_open_complaints, number_of_policies, total_claim_amount   
'''

mkt.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
mkt.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
null_data = mkt.isna().any(axis = 1)
mkt[null_data]
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 4               4  QA50777      Oregon              9025.067525       No
# 5               5  HO81102         NaN              4745.181764      NaN
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10900       10900  VN73653      Oregon              6423.739052       No
# 10901       10901  RY92254  Washington              4547.892543       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
#percentage of missing values by variable

mkt.isna().sum() / len(mkt)
# Out:
# unnamed:_0                       0.000000
# customer                         0.000000
# state                            0.057837
# customer_lifetime_value          0.000000
# response                         0.057837
# coverage                         0.000000
# education                        0.000000
# effective_to_date                0.000000
# employmentstatus                 0.000000
# gender                           0.000000
# income                           0.000000
# location_code                    0.000000
# marital_status                   0.000000
# monthly_premium_auto             0.000000
# months_since_last_claim          0.058020
# months_since_policy_inception    0.000000
# number_of_open_complaints        0.058020
# number_of_policies               0.000000
# policy_type                      0.000000
# policy                           0.000000
# renew_offer_type                 0.000000
# sales_channel                    0.000000
# ...

# %%
#as variable vehicle_type has more than 50% of missing values let's drop it

mkt = mkt.drop('vehicle_type',axis="columns")
mkt
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
#checking total income

mkt['income'].sum()
# Out:
# 409520867

# %%
#checking total income if remaining missing values are dropped

mkt_temp=mkt.dropna()

mkt_temp['income'].sum()
# Out:
# 343962509

# %%
#percentage of total income lost if remaining missing values are dropped (16%)

1-(mkt_temp['income'].sum()/mkt['income'].sum())
# Out:
# 0.16008551280977823

# %%
'''
At this point we need to take a decision. 
If we consider 16% is not too much from the business point of view we could simply drop the remaining missing values
Otherwise we could follow other approach as replacing missing values by mean/mode, or using a regression

In this case, let's drop the remaining missing values (mkt_temp)
'''
# Out:
# "\nAt this point we need to take a decision. \nIf we consider 16% is not too much from the business point of view we could simply drop the remaining missing values\nOtherwise we could follow other approach as replacing missing values by mean/mode, or using a regression\n\nIn this case, let's drop the remaining missing values (mkt_temp)\n"

# %%
mkt_temp['effective_to_date_2']=pd.to_datetime(mkt_temp['effective_to_date'])
mkt_temp
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
mkt_temp.dtypes
# Out:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                        object
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# ...

# %%
mkt_temp['month']=mkt_temp['effective_to_date_2'].dt.month
mkt_temp
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 6               6  IW72280  California              5035.035257       No
# ...           ...      ...         ...                      ...      ...
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
#There is only data for January and February so there is no need to filter the information for the first quarter
mkt_temp.groupby(['month'])['customer'].count()
# Out:
# month
# 1    4898
# 2    4236
# Name: customer, dtype: int64

# %%
mkt_temp['effective_to_date'].unique()
# Out:
# array(['2/18/11', '1/18/11', '2/10/11', '1/11/11', '2/14/11', '2/24/11',
#        '1/19/11', '1/4/11', '1/2/11', '1/31/11', '1/26/11', '2/28/11',
#        '1/16/11', '2/7/11', '1/17/11', '2/26/11', '2/23/11', '1/15/11',
#        '2/15/11', '1/24/11', '2/21/11', '2/22/11', '1/7/11', '1/28/11',
#        '2/8/11', '2/12/11', '2/20/11', '1/5/11', '2/19/11', '1/3/11',
#        '2/3/11', '1/22/11', '1/23/11', '2/5/11', '2/13/11', '1/25/11',
#        '2/16/11', '2/1/11', '1/27/11', '1/12/11', '1/20/11', '2/11/11',
#        '1/21/11', '1/29/11', '2/9/11', '2/27/11', '2/17/11', '1/6/11',
#        '2/2/11', '1/9/11', '1/14/11', '2/25/11', '1/10/11', '2/6/11',
#        '1/13/11', '1/1/11', '2/4/11', '1/8/11', '1/30/11'], dtype=object)
