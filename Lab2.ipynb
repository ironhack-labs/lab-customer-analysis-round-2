# %%
import numpy as np
import pandas as pd

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')

# %%
file1.shape
# Out:
# (10910, 26)

# %%
file1.columns = file1.columns.str.lower().str.replace(' ', '_')
file1.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %%
numericalcol=file1._get_numeric_data()
numericalcol
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
objectcol=file1.select_dtypes('object')
objectcol
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
file1.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
file1.isna().sum()/len(file1)*100
# Out:
# unnamed:_0                        0.000000
# customer                          0.000000
# state                             5.783685
# customer_lifetime_value           0.000000
# response                          5.783685
# coverage                          0.000000
# education                         0.000000
# effective_to_date                 0.000000
# employmentstatus                  0.000000
# gender                            0.000000
# income                            0.000000
# location_code                     0.000000
# marital_status                    0.000000
# monthly_premium_auto              0.000000
# months_since_last_claim           5.802016
# months_since_policy_inception     0.000000
# number_of_open_complaints         5.802016
# number_of_policies                0.000000
# policy_type                       0.000000
# policy                            0.000000
# renew_offer_type                  0.000000
# sales_channel                     0.000000
# ...

# %%
file1.drop(['vehicle_type'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2684\3855296108.py in <module>
# ----> 1 file1.drop(['vehicle_type'],axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
file1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
file1.drop(['unnamed:_0'],axis=1,inplace=True)

# %%
file1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
nulls_df = pd.DataFrame(file1.isna().sum()/len(file1)).reset_index()
nulls_df.columns = ['column_name','percent_nulls']

# %%
columns_to_change = nulls_df[nulls_df['percent_nulls']>0.00]['column_name'].values

# %%
columns_to_change
# Out:
# array(['state', 'response', 'months_since_last_claim',
#        'number_of_open_complaints', 'vehicle_class', 'vehicle_size'],
#       dtype=object)

# %%
file1.drop_duplicates()
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
nulls_df = pd.DataFrame(file1.isna().sum()/len(file1)).reset_index()
nulls_df.columns = ['column_name','percent_nulls']
nulls_df
# Out:
#                       column_name  percent_nulls
# 0                        customer       0.000000
# 1                           state       0.057837
# 2         customer_lifetime_value       0.000000
# 3                        response       0.057837
# 4                        coverage       0.000000
# 5                       education       0.000000
# 6               effective_to_date       0.000000
# 7                employmentstatus       0.000000
# 8                          gender       0.000000
# 9                          income       0.000000
# 10                  location_code       0.000000
# 11                 marital_status       0.000000
# 12           monthly_premium_auto       0.000000
# 13        months_since_last_claim       0.058020
# 14  months_since_policy_inception       0.000000
# 15      number_of_open_complaints       0.058020
# 16             number_of_policies       0.000000
# 17                    policy_type       0.000000
# ...

# %%
data1=file1.dropna(axis=0)
data1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
data1.isna().sum()/len(data1)*100
# Out:
# customer                         0.0
# state                            0.0
# customer_lifetime_value          0.0
# response                         0.0
# coverage                         0.0
# education                        0.0
# effective_to_date                0.0
# employmentstatus                 0.0
# gender                           0.0
# income                           0.0
# location_code                    0.0
# marital_status                   0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# policy_type                      0.0
# policy                           0.0
# renew_offer_type                 0.0
# sales_channel                    0.0
# total_claim_amount               0.0
# vehicle_class                    0.0
# vehicle_size                     0.0
# dtype: float64

# %%
import warnings 
warnings.filterwarnings("ignore")

data1['effective_to_date'] = pd.to_datetime(data1['effective_to_date'],errors='coerce')
data1['effective_to_date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 6       2011-02-14
#            ...
# 10903   2011-01-07
# 10904   2011-02-24
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# Name: effective_to_date, Length: 9134, dtype: datetime64[ns]

# %%
data1['effective_to_date'][0].month
# Out:
# 2

# %%
data1['month'] = pd.DatetimeIndex(data1['effective_to_date']).month

# %%
data1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
data1 = data1[data1['month'].isin([1, 2, 3])]
data1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
data1[data1['month']=='3']
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, month]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# # BONUS

# %%
def clean_data(data1):
    import pandas as pd
    import numpy as np

    data1 = pd.read_csv(data1)
    print("Data shape:", data1.shape)

    data1.columns = data1.columns.str.lower().str.replace(' ', '')
    print("Standardized data columns: ", data1.columns)

    numerical_cols = data1.select_dtypes(include=['int', 'float']).columns
    print("Numerical Columns: ", numerical_cols)

    categorical_cols = data1.select_dtypes(include=['object']).columns
    print("Categorical Columns: ", categorical_cols)

    # clean data
    nulls_df = pd.DataFrame(data1.isna().sum() / len(data1) * 100).reset_index()  # formatar em tabela
    nulls_df.columns = ['column_name', 'percent_nulls']

    columns_to_drop = nulls_df[nulls_df['percent_nulls'] >= 50]['column_name'].values
    data1 = data1.drop(columns_to_drop, axis=1)

    data1 = data1.drop_duplicates()

    data1 = data1.dropna(axis=0)

    import warnings

    warnings.filterwarnings("ignore")

    data1['effectivetodate'] = pd.to_datetime(data1['effectivetodate'], errors='coerce')
    data1['month'] = data1['effectivetodate'].dt.month

    data1 = data1[data1['month'].isin([1, 2, 3])]

    print("Final data filtered is: ")

    return pd.DataFrame(data1)


# test
clean_data("marketing_customer_analysis.csv")
# Out:
# Data shape: (10910, 26)
# Standardized data columns:  Index(['unnamed:0', 'customer', 'state', 'customerlifetimevalue', 'response',
#        'coverage', 'education', 'effectivetodate', 'employmentstatus',
#        'gender', 'income', 'locationcode', 'maritalstatus',
#        'monthlypremiumauto', 'monthssincelastclaim',
#        'monthssincepolicyinception', 'numberofopencomplaints',
#        'numberofpolicies', 'policytype', 'policy', 'renewoffertype',
#        'saleschannel', 'totalclaimamount', 'vehicleclass', 'vehiclesize',
#        'vehicletype'],
#       dtype='object')
# Numerical Columns:  Index(['unnamed:0', 'customerlifetimevalue', 'income', 'monthlypremiumauto',
#        'monthssincelastclaim', 'monthssincepolicyinception',
#        'numberofopencomplaints', 'numberofpolicies', 'totalclaimamount'],
#       dtype='object')
# Categorical Columns:  Index(['customer', 'state', 'response', 'coverage', 'education',
# ...
