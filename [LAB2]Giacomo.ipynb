# %%
import pandas as pd

# %%
#importing dataset
customer = pd.read_csv("/Users/giacomorossini/Desktop/IRONHACK/Class/LAB2/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv")
customer
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#analyzing the shape
customer.shape
# Out:
# (10910, 26)

# %%
#performing data header cleaning 
cols = []

for i in range(len(customer.columns)):
    cols.append(customer.columns[i].lower().replace(' ','_'))
    
customer.columns=cols
customer
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
#performing rename of column unnamed:_0 --> could be dropped since it seems = to the index of the dataset
customer= customer.rename(columns = {'unnamed:_0': 'index'})
customer
# Out:
#        index customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# ...      ...      ...         ...                      ...      ...       ...
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
# 10909  10909  IV32877         NaN              6857.519928      NaN     Basic
#
# ...

# %%
#checking column numerical | categorical 
customer.dtypes #numerical: int64|float64 , categorical: object
# Out:
# index                              int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
#deal with NaN values
#1
customer.isnull()
# Out:
#        index  customer  state  customer_lifetime_value  response  coverage  \
# 0      False     False  False                    False     False     False
# 1      False     False  False                    False     False     False
# 2      False     False  False                    False     False     False
# 3      False     False  False                    False     False     False
# 4      False     False  False                    False     False     False
# ...      ...       ...    ...                      ...       ...       ...
# 10905  False     False  False                    False     False     False
# 10906  False     False  False                    False     False     False
# 10907  False     False  False                    False     False     False
# 10908  False     False  False                    False     False     False
# 10909  False     False   True                    False      True     False
#
# ...

# %%
#2
customer.isnull().sum()
# Out:
# index                               0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
#3

condition = customer.isnull().any(axis=1)
customer[condition]
# Out:
#        index customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 4          4  QA50777      Oregon              9025.067525       No   Premium
# 5          5  HO81102         NaN              4745.181764      NaN     Basic
# 6          6  IW72280  California              5035.035257       No     Basic
# ...      ...      ...         ...                      ...      ...       ...
# 10900  10900  VN73653      Oregon              6423.739052       No     Basic
# 10901  10901  RY92254  Washington              4547.892543       No   Premium
# 10905  10905  FE99816      Nevada             15563.369440       No   Premium
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10909  10909  IV32877         NaN              6857.519928      NaN     Basic
#
# ...

# %%
#clearing dataset from N#A (not saving in a new dataset --> excess of lost info)

customer.dropna()
# Out:
#        index customer       state  customer_lifetime_value response  coverage  \
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 10        10  HG93801     Arizona              5154.764074       No  Extended
# 13        13  KR82385  California              5454.587929       No     Basic
# 16        16  FH51383  California              5326.677654       No     Basic
# ...      ...      ...         ...                      ...      ...       ...
# 10902  10902  PP30874  California              3579.023825       No  Extended
# 10903  10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10908  10908  WA60547  California             11971.977650       No   Premium
#
# ...

# %%
customer['response']= customer['response'].fillna('No')
customer['number_of_open_complaints']=customer['number_of_open_complaints'].fillna('0.0')

# %%
customer['vehicle_type'].unique()
# Out:
# array([nan, 'A'], dtype=object)

# %%
#not a valuable indicator --> filled w/ 'A'
customer['vehicle_type'] = customer['vehicle_type'].fillna('A')

# %%
customer=customer.dropna()
customer
# Out:
#        index customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 6          6  IW72280  California              5035.035257       No     Basic
# ...      ...      ...         ...                      ...      ...       ...
# 10903  10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
#
# ...

# %%
#confirmation all datas are from the first quarter
customer['effective_to_date'].unique()
# Out:
# array(['2/18/11', '1/18/11', '2/10/11', '1/11/11', '2/14/11', '2/24/11',
#        '1/19/11', '1/4/11', '1/2/11', '1/31/11', '1/26/11', '2/28/11',
#        '1/16/11', '2/7/11', '1/17/11', '2/26/11', '2/23/11', '1/15/11',
#        '2/15/11', '1/24/11', '2/21/11', '2/22/11', '1/7/11', '1/28/11',
#        '2/8/11', '2/12/11', '2/20/11', '1/5/11', '2/19/11', '1/3/11',
#        '2/3/11', '1/22/11', '1/23/11', '2/5/11', '2/13/11', '1/25/11',
#        '2/16/11', '2/1/11', '1/27/11', '1/12/11', '1/20/11', '2/11/11',
#        '1/21/11', '1/29/11', '2/9/11', '2/27/11', '2/17/11', '1/6/11',
#        '2/2/11', '1/9/11', '1/14/11', '2/25/11', '1/10/11', '2/6/11',
#        '1/13/11', '1/1/11', '2/4/11', '1/8/11', '1/30/11'], dtype=object)

# %%
customer['effective_to_date'] = pd.to_datetime(customer['effective_to_date'], errors='coerce')
customer ['month']= customer['effective_to_date'].dt.month
customer['month']
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 6        2
#         ..
# 10903    1
# 10904    2
# 10906    1
# 10907    2
# 10908    2
# Name: month, Length: 9134, dtype: int64

# %%
customer['month'].unique()
# Out:
# array([2, 1])

# %%
#filtering first quarter = 1,2,3 

condition = customer['month']<=3
customer[condition]
# Out:
#        index customer       state  customer_lifetime_value response  coverage  \
# 0          0  DK49336     Arizona              4809.216960       No     Basic
# 1          1  KX64629  California              2228.525238       No     Basic
# 2          2  LZ68649  Washington             14947.917300       No     Basic
# 3          3  XL78013      Oregon             22332.439460      Yes  Extended
# 6          6  IW72280  California              5035.035257       No     Basic
# ...      ...      ...         ...                      ...      ...       ...
# 10903  10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  10908  WA60547  California             11971.977650       No   Premium
#
# ...

# %%
#trasformation in a DEF for headers uniform.

def transformation (df1):
    cols=[]
    for i in range(len(df1.columns)):
        cols.append(df1.columns[i].lower().replace(' ','_'))
        
    df1.columns=cols
    
    
transformation(customer)
