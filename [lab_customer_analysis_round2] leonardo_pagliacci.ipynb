# %%
import pandas as pd
import numpy as np

customer_da = pd.read_csv("/Users/leozinho.air/Desktop/ironhack_da/class_04/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv")
customer_da
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
# 1. Show the dataframe shape.

customer_da.shape # (10910, 26)
# Out:
# (10910, 26)

# %%
# 2. Standardize header names.

columns = []

for i in range(len(customer_da.columns)):
    columns.append(customer_da.columns[i].lower().replace(' ', '_'))

customer_da.columns = columns

customer_da

# Dropping the column 'unnamed:_0'

customer_da = customer_da.drop(['unnamed:_0'], axis = 1)

customer_da
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
# Which columns are numerical?
# Which columns are categorical?

# customer_da.dtypes

df_numerical = customer_da.select_dtypes(include='number')

columns_num = []

for i in range(len(df_numerical.columns)):
    columns_num.append(df_numerical.columns[i])
print('Numerical columns are: ', columns_num)

print('\n')
df_categorical = customer_da.select_dtypes(include='object')

columns_cat = []

for i in range(len(df_categorical.columns)):
    columns_cat.append(df_categorical.columns[i])
print('Categorical columns are: ', columns_cat)
# Out:
# Numerical columns are:  ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies', 'total_claim_amount']
#
#
# Categorical columns are:  ['customer', 'state', 'response', 'coverage', 'education', 'effective_to_date', 'employmentstatus', 'gender', 'location_code', 'marital_status', 'policy_type', 'policy', 'renew_offer_type', 'sales_channel', 'vehicle_class', 'vehicle_size', 'vehicle_type']

# %%
# Check and deal with `NaN` values.

customer_da.isna()

customer_da.isna().sum().sum() # 9254 missing values

# I store the 'Nan' values in a variable and use it as a condition

condition = customer_da.isnull().any(axis = 1) # customer_da.isnull() is a DataFrame operation that checks for NaN (missing) values in each cell of the DataFrame customer_da. It returns a DataFrame of the same shape as customer_da but with Boolean values, where True indicates a NaN value and False indicates a non-NaN value.

customer_da[condition]

# Percentage of Nan values 

customer_da.isna().sum()/ len(customer_da)

customer_da.isna().sum()

# Understanding the meaning of the Nan values:

#customer_da[condition]['response']    
#customer_da[condition]['months_since_last_claim']
#customer_da[condition]['state']
#customer_da[condition]['months_since_last_claim']
#customer_da[condition]['number_of_open_complaints']
#customer_da[condition]['vehicle_class']
#customer_da[condition]['vehicle_size']
#customer_da[condition]['vehicle_type']
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %%
customer_da['vehicle_type'].unique() 

# The only values are Nan or vehicle class 'A', i will opt to create a new df without the column.

customer_da = customer_da.drop(['vehicle_type'], axis = 1)

customer_da
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
customer_da.isna().sum()

# Checking the unique values for better understanding

customer_da['state'].unique() # 'Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'

customer_da['response'].unique() # 'No', 'Yes', nan

customer_da['months_since_last_claim'].unique() # Here i could put the mean of all the values

customer_da['number_of_open_complaints'].unique()# 0., nan,  3.,  1.,  2.,  4.,  5 -> here, i also could use the mean to fill

customer_da['vehicle_class'].unique()  # 'Four-Door Car', 'SUV', 'Two-Door Car', 'Sports Car', 'Luxury Car','Luxury SUV', nan

customer_da['vehicle_size'].unique() # 'Medsize', 'Small', 'Large', nan

# 1° solution: 

# I will only fill the Nan of 'months_since_last_claim' and 'number_of_open_complaints' since they are numerical.

# customer_da['months_since_last_claim'] = customer_da['months_since_last_claim'].fillna(customer_da['months_since_last_claim'].mean())

# customer_da['number_of_open_complaints'] = customer_da['number_of_open_complaints'].fillna(customer_da['number_of_open_complaints'].mean())


# 2° solution: (what i chose)

customer_da['income'].sum() # 409,520,867 total income

customer_no_nan = customer_da.dropna()

customer_no_nan['income'].sum() # 343,962,509 income with no Nan -> -15 % of the original df


# From now i will use the 'customer_no_nan' df
# Out:
# 343962509

# %%
# Datetime format - Extract the months from the dataset and store in a separate column. 
# Then filter the data to show only the information for the first quarter , ie. January, February and March.
# _Hint_: If data from March does not exist, consider only January and February.

# Converting to date-time dtype

customer_no_nan['effective_to_date'] = pd.to_datetime(customer_no_nan['effective_to_date'])


customer_no_nan['month'] = customer_no_nan['effective_to_date'].dt.month


customer_no_nan
# Out:
# /var/folders/yb/9gxqx77n4nq_ls51pf25lnvw0000gn/T/ipykernel_64370/3475213289.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_no_nan['effective_to_date'] = pd.to_datetime(customer_no_nan['effective_to_date'])
# /var/folders/yb/9gxqx77n4nq_ls51pf25lnvw0000gn/T/ipykernel_64370/3475213289.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_no_nan['month'] = customer_no_nan['effective_to_date'].dt.month
# ...

# %%
customer_no_nan['month'].loc[1000:1050] # March doesn't seem to be present. Let's make some more line to check it out

march_present = customer_no_nan[customer_no_nan['month'] == 3] # I made a variable that gives us  a bool values if it finds the month of March inside the df

if not march_present.empty: # This check if it's empty or not. If it's not empty, it means there are records for March.
    print('March is not present')
else:
    print('There is not March inside.')
# Out:
# There is not March inside.

# %%
condition = (customer_no_nan['month'] == 1) | (customer_no_nan['month'] == 2)

customer_Q1 = customer_no_nan[condition]

customer_Q1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
# Now i convert the month number in 'number' column to the actual month names

month_names = []

month_name_list = ['January', 'February']

# Iterate through the month column and convert to month names
for i in customer_Q1['month']:
    month_name = month_name_list[i - 1]
    month_names.append(month_name)

# Create a new column in the DataFrame with the month names
customer_Q1['month'] = month_names

customer_Q1
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
# BONUS: Put all the previously mentioned data transformations into a function.


def df_cleaning(original_df):
    '''
    The following function will execute these cleaning operations:
    
        1. Show the dataframe shape.
        2. Standardize header names.
        3. Which columns are numerical?
        4. Which columns are categorical?
        5. Check and deal with `NaN` values.
        6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. _Hint_: If data from March does not exist, consider only January and February.
    '''
    
    # 1. Show the dataframe shape.
    print('This is the df shape', original_df.shape)
    
    print('\n')
    
    # 2. Standardize header names.
    
    original_df = original_df.drop(['Unnamed: 0'], axis = 1) # Dropping the column 'unnamed:_0'
    
    columns = []

    for i in range(len(original_df.columns)):
        columns.append(original_df.columns[i].lower().replace(' ', '_'))

    original_df.columns = columns
    
    # 3. Which columns are numerical?
    # 4. Which columns are categorical?
    
    df_numerical = original_df.select_dtypes(include='number')

    columns_num = []

    for i in range(len(df_numerical.columns)):
        columns_num.append(df_numerical.columns[i])
    print('Numerical columns are: ', columns_num)

    print('\n')
    df_categorical = original_df.select_dtypes(include='object')

    columns_cat = []

    for i in range(len(df_categorical.columns)):
        columns_cat.append(df_categorical.columns[i])
    print('Categorical columns are: ', columns_cat)
    
    # 5. Check and deal with `NaN` values.
    
    original_df = original_df.drop(['vehicle_type'], axis=1) # This line works only if it present the 'vehicle_type' column

    df_no_nan = original_df.dropna() # Here i am dropping all of Nan values because of the properties of this specific df

    # 6. Date-time convertion + creating 'month' column + filtering df by Q1
    
    df_no_nan['effective_to_date'] = pd.to_datetime(df_no_nan['effective_to_date'])


    df_no_nan['month'] = df_no_nan['effective_to_date'].dt.month

    # Let's check if March present. If it is present i will filter Q1 just by January and February
    
    march_present = df_no_nan[df_no_nan['month'] == 3]
    
    if not march_present.empty:
        condition = (df_no_nan['month'] == 1) | (df_no_nan['month'] == 2)

        customer_Q1 = df_no_nan[condition]
    else:
        condition = (df_no_nan['month'] >= 1) | (df_no_nan['month'] <= 3)

        customer_Q1 = df_no_nan[condition]
    
    month_names = []

    month_name_list = ['January', 'February', 'March']

    # Iterate through the month column and convert to month names
    for i in customer_Q1['month']:
        month_name = month_name_list[i - 1]
        month_names.append(month_name)

    # Create a new column in the DataFrame with the month names
    customer_Q1['month'] = month_names

    return customer_Q1

# %%
# The following function works only on the raw dataframe stored in 'marketing_customer_analysis.csv' file

df_cleaning(customer_da)
# Out:
# This is the df shape (10910, 24)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[126], line 3
#       1 # The following called function works only on the raw dataframe stored in 'marketing_customer_analysis.csv' file
# ----> 3 df_cleaning(customer_da)
#
# Cell In[125], line 23, in df_cleaning(original_df)
#      19 print('\n')
#      21 # 2. Standardize header names.
# ---> 23 original_df = original_df.drop(['Unnamed: 0'], axis = 1) # Dropping the column 'unnamed:_0'
#      25 columns = []
#      27 for i in range(len(original_df.columns)):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...
