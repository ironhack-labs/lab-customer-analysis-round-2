# %%
import pandas as pd
import numpy as np

# %%
root_csv = r'C:\Users\aidag\OneDrive\Escritorio\ironhack\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv'
df_original = pd.read_csv(root_csv)
df_copy = df_original.copy()

dimensions = df_copy.shape
print("The dimensions of this dataframe is", dimensions)
# Out:
# The dimensions of this dataframe is (10910, 26)

# %%
df_copy.columns = df_original.columns.str.upper()
df_copy.head() #standarize in uppercase
# Out:
#    UNNAMED: 0 CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    COVERAGE EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS GENDER  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    NUMBER OF OPEN COMPLAINTS NUMBER OF POLICIES     POLICY TYPE        POLICY  \
# ...

# %%
df_copy.dtypes
# Out:
# UNNAMED: 0                         int64
# CUSTOMER                          object
# STATE                             object
# CUSTOMER LIFETIME VALUE          float64
# RESPONSE                          object
# COVERAGE                          object
# EDUCATION                         object
# EFFECTIVE TO DATE                 object
# EMPLOYMENTSTATUS                  object
# GENDER                            object
# INCOME                             int64
# LOCATION CODE                     object
# MARITAL STATUS                    object
# MONTHLY PREMIUM AUTO               int64
# MONTHS SINCE LAST CLAIM          float64
# MONTHS SINCE POLICY INCEPTION      int64
# NUMBER OF OPEN COMPLAINTS        float64
# NUMBER OF POLICIES                 int64
# POLICY TYPE                       object
# POLICY                            object
# RENEW OFFER TYPE                  object
# SALES CHANNEL                     object
# TOTAL CLAIM AMOUNT               float64
# ...

# %%
print("Numerical columns are: UNNAMED, CUSTOMER LIFETIME VALUE, INCOME, MONTHLY PREMIUM AUTO,MONTHLY PREMIUM AUTO, MONTHS SINCE LAST CLAIM, MONTHS SINCE POLICY INCEPTION, NUMBER OF OPEN COMPLAINTS, NUMBER OF POLICIES and TOTAL CLAIM AMOUNT, the rest are categorical values ")
# Out:
# Numerical columns are: UNNAMED, CUSTOMER LIFETIME VALUE, INCOME, MONTHLY PREMIUM AUTO,MONTHLY PREMIUM AUTO, MONTHS SINCE LAST CLAIM, MONTHS SINCE POLICY INCEPTION, NUMBER OF OPEN COMPLAINTS, NUMBER OF POLICIES and TOTAL CLAIM AMOUNT, the rest are categorical values

# %%
df_copy.isna().sum()
# Out:
# UNNAMED: 0                          0
# CUSTOMER                            0
# STATE                             631
# CUSTOMER LIFETIME VALUE             0
# RESPONSE                          631
# COVERAGE                            0
# EDUCATION                           0
# EFFECTIVE TO DATE                   0
# EMPLOYMENTSTATUS                    0
# GENDER                              0
# INCOME                              0
# LOCATION CODE                       0
# MARITAL STATUS                      0
# MONTHLY PREMIUM AUTO                0
# MONTHS SINCE LAST CLAIM           633
# MONTHS SINCE POLICY INCEPTION       0
# NUMBER OF OPEN COMPLAINTS         633
# NUMBER OF POLICIES                  0
# POLICY TYPE                         0
# POLICY                              0
# RENEW OFFER TYPE                    0
# SALES CHANNEL                       0
# TOTAL CLAIM AMOUNT                  0
# VEHICLE CLASS                     622
# VEHICLE SIZE                      622
# ...

# %%
df_copy = df_copy.dropna(subset=["STATE", "RESPONSE", "MONTHS SINCE LAST CLAIM", "NUMBER OF OPEN COMPLAINTS", "VEHICLE CLASS", "VEHICLE SIZE", "VEHICLE TYPE"]) 
df_copy
# Out:
#        UNNAMED: 0 CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        COVERAGE             EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS  \
# ...

# %%
df_copy['EFFECTIVE TO DATE'] = pd.to_datetime(df_copy['EFFECTIVE TO DATE'])
df_copy['MONTH'] = df_copy['EFFECTIVE TO DATE'].dt.month
first_trimester = df_copy[(df_copy['MONTH'] >= 1) & (df_copy['MONTH'] <= 3)] #considerinf january, february and march, this three months
first_trimester
# Out:
#        UNNAMED: 0 CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        COVERAGE             EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS  \
# ...
