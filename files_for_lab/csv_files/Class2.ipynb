# %%
import pandas as pd
import numpy as np
data = pd.read_csv('marketing_customer_analysis.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0  Customer Lifetime Value        Income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Months Since Last Claim  \
# count          10910.000000             10277.000000
# mean              93.196059                15.149071
# std               34.442532                10.080349
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
data.describe(include=[float])
# Out:
#        Customer Lifetime Value  Months Since Last Claim  \
# count             10910.000000             10277.000000
# mean               8018.241094                15.149071
# std                6885.081434                10.080349
# min                1898.007675                 0.000000
# 25%                4014.453113                 6.000000
# 50%                5771.147235                14.000000
# 75%                8992.779137                23.000000
# max               83325.381190                35.000000
#
#        Number of Open Complaints  Total Claim Amount
# count               10277.000000        10910.000000
# mean                    0.384256          434.888330
# std                     0.912457          292.180556
# min                     0.000000            0.099007
# 25%                     0.000000          271.082527
# 50%                     0.000000          382.564630
# 75%                     0.000000          547.200000
# ...

# %%
data.describe().T # transpose (rows to columns / columns to rows)
# Out:
#                                  count          mean           std  \
# Unnamed: 0                     10910.0   5454.500000   3149.590053
# Customer Lifetime Value        10910.0   8018.241094   6885.081434
# Income                         10910.0  37536.284785  30359.195670
# Monthly Premium Auto           10910.0     93.196059     34.442532
# Months Since Last Claim        10277.0     15.149071     10.080349
# Months Since Policy Inception  10910.0     48.091934     27.940675
# Number of Open Complaints      10277.0      0.384256      0.912457
# Number of Policies             10910.0      2.979193      2.399359
# Total Claim Amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# Unnamed: 0                        0.000000  2727.250000   5454.500000
# Customer Lifetime Value        1898.007675  4014.453113   5771.147235
# Income                            0.000000     0.000000  33813.500000
# ...

# %%
summary = data.describe().T

# %%
summary['iqr'] = summary['75%'] - summary['25%'] #iqr = interquarter range

# %%
print("population mean =", round(np.mean(population),2))
print("population standard deviation = ",round(n.std(population),2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5032\2296295901.py in <module>
# ----> 1 print("population mean =", round(np.mean(population),2))
#       2 print("population standard deviation = ",round(n.std(population),2))
#
# NameError: name 'population' is not defined
