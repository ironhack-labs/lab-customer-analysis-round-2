# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv("marketing_customer_analysis.csv")

# %%
#1 - dataframe shape
file1.shape
# Out:
# (10910, 26)

# %%
file1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#2 Standardize header names.

# %%
file1.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
cols=[]
for column in range(len(file1.columns)):
    cols.append(file1.columns[column].lower())
file1.columns = cols

# %%
file1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
#3 Which columns are numerical?
file1._get_numeric_data()
# Out:
#        unnamed: 0  customer lifetime value  income  monthly premium auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# ...

# %%
#4 Which columns are categorical?
file1.select_dtypes('object')
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %%
#5 Check and deal with NaN values.
file1.isna()
# Out:
#        unnamed: 0  customer  state  customer lifetime value  response  \
# 0           False     False  False                    False     False
# 1           False     False  False                    False     False
# 2           False     False  False                    False     False
# 3           False     False  False                    False     False
# 4           False     False  False                    False     False
# ...           ...       ...    ...                      ...       ...
# 10905       False     False  False                    False     False
# 10906       False     False  False                    False     False
# 10907       False     False  False                    False     False
# 10908       False     False  False                    False     False
# 10909       False     False   True                    False      True
#
#        coverage  education  effective to date  employmentstatus  gender  ...  \
# ...

# %%
file1.isna().sum()/len(file1)*100
# Out:
# unnamed: 0                        0.000000
# customer                          0.000000
# state                             5.783685
# customer lifetime value           0.000000
# response                          5.783685
# coverage                          0.000000
# education                         0.000000
# effective to date                 0.000000
# employmentstatus                  0.000000
# gender                            0.000000
# income                            0.000000
# location code                     0.000000
# marital status                    0.000000
# monthly premium auto              0.000000
# months since last claim           5.802016
# months since policy inception     0.000000
# number of open complaints         5.802016
# number of policies                0.000000
# policy type                       0.000000
# policy                            0.000000
# renew offer type                  0.000000
# sales channel                     0.000000
# ...

# %%
file1.drop(['unnamed: 0'],axis=1, inplace=True)

# %%
nulls=pd.DataFrame(file1.isna().sum()/len(file1)).reset_index()

# %%
nulls.columns = ['column_name','percent_nulls']

# %%
nulls
# Out:
#                       column_name  percent_nulls
# 0                        customer       0.000000
# 1                           state       0.057837
# 2         customer lifetime value       0.000000
# 3                        response       0.057837
# 4                        coverage       0.000000
# 5                       education       0.000000
# 6               effective to date       0.000000
# 7                employmentstatus       0.000000
# 8                          gender       0.000000
# 9                          income       0.000000
# 10                  location code       0.000000
# 11                 marital status       0.000000
# 12           monthly premium auto       0.000000
# 13        months since last claim       0.058020
# 14  months since policy inception       0.000000
# 15      number of open complaints       0.058020
# 16             number of policies       0.000000
# 17                    policy type       0.000000
# ...

# %%
nulls['percent_nulls']>= 0.05
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23     True
# 24     True
# Name: percent_nulls, dtype: bool

# %%
nulls[nulls['percent_nulls']>= 0.05]
# Out:
#                   column_name  percent_nulls
# 1                       state       0.057837
# 3                    response       0.057837
# 13    months since last claim       0.058020
# 15  number of open complaints       0.058020
# 22              vehicle class       0.057012
# 23               vehicle size       0.057012
# 24               vehicle type       0.502475

# %%
todrop=nulls[nulls['percent_nulls']>= 0.05]['column_name'].values

# %%
file1.drop(todrop,axis=1, inplace=True)

# %%
file1
# Out:
#       customer  customer lifetime value  coverage education effective to date  \
# 0      DK49336              4809.216960     Basic   College           2/18/11
# 1      KX64629              2228.525238     Basic   College           1/18/11
# 2      LZ68649             14947.917300     Basic  Bachelor           2/10/11
# 3      XL78013             22332.439460  Extended   College           1/11/11
# 4      QA50777              9025.067525   Premium  Bachelor           1/17/11
# ...        ...                      ...       ...       ...               ...
# 10905  FE99816             15563.369440   Premium  Bachelor           1/19/11
# 10906  KX53892              5259.444853     Basic   College            1/6/11
# 10907  TL39050             23893.304100  Extended  Bachelor            2/6/11
# 10908  WA60547             11971.977650   Premium   College           2/13/11
# 10909  IV32877              6857.519928     Basic  Bachelor            1/8/11
#
# ...

# %%
#6 Datetime format - Extract the months from the dataset and store in a separate column.

# %%
import time 

from datetime import date

# %%
file1.dtypes
# Out:
# customer                                 object
# customer lifetime value                 float64
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since policy inception             int64
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# sales channel                            object
# total claim amount                      float64
# dtype: object

# %%
file1['month'] = pd.DatetimeIndex(file1['effective to date']).month #I searched online - is it right?

# %%
file1
# Out:
#       customer  customer lifetime value  coverage education effective to date  \
# 0      DK49336              4809.216960     Basic   College        2011-02-18
# 1      KX64629              2228.525238     Basic   College        2011-01-18
# 2      LZ68649             14947.917300     Basic  Bachelor        2011-02-10
# 3      XL78013             22332.439460  Extended   College        2011-01-11
# 4      QA50777              9025.067525   Premium  Bachelor        2011-01-17
# ...        ...                      ...       ...       ...               ...
# 10905  FE99816             15563.369440   Premium  Bachelor        2011-01-19
# 10906  KX53892              5259.444853     Basic   College        2011-01-06
# 10907  TL39050             23893.304100  Extended  Bachelor        2011-02-06
# 10908  WA60547             11971.977650   Premium   College        2011-02-13
# 10909  IV32877              6857.519928     Basic  Bachelor        2011-01-08
#
# ...

# %%
# filter the data - first quarter

# %%
file1[file1['month'] < 4] #i tried below other approach - is this one right too?
# Out:
#       customer  customer lifetime value  coverage education effective to date  \
# 0      DK49336              4809.216960     Basic   College        2011-02-18
# 1      KX64629              2228.525238     Basic   College        2011-01-18
# 2      LZ68649             14947.917300     Basic  Bachelor        2011-02-10
# 3      XL78013             22332.439460  Extended   College        2011-01-11
# 4      QA50777              9025.067525   Premium  Bachelor        2011-01-17
# ...        ...                      ...       ...       ...               ...
# 10905  FE99816             15563.369440   Premium  Bachelor        2011-01-19
# 10906  KX53892              5259.444853     Basic   College        2011-01-06
# 10907  TL39050             23893.304100  Extended  Bachelor        2011-02-06
# 10908  WA60547             11971.977650   Premium   College        2011-02-13
# 10909  IV32877              6857.519928     Basic  Bachelor        2011-01-08
#
# ...

# %%
file1[file1['month'].isin([1,2,3])]
# Out:
#       customer  customer lifetime value  coverage education effective to date  \
# 0      DK49336              4809.216960     Basic   College        2011-02-18
# 1      KX64629              2228.525238     Basic   College        2011-01-18
# 2      LZ68649             14947.917300     Basic  Bachelor        2011-02-10
# 3      XL78013             22332.439460  Extended   College        2011-01-11
# 4      QA50777              9025.067525   Premium  Bachelor        2011-01-17
# ...        ...                      ...       ...       ...               ...
# 10905  FE99816             15563.369440   Premium  Bachelor        2011-01-19
# 10906  KX53892              5259.444853     Basic   College        2011-01-06
# 10907  TL39050             23893.304100  Extended  Bachelor        2011-02-06
# 10908  WA60547             11971.977650   Premium   College        2011-02-13
# 10909  IV32877              6857.519928     Basic  Bachelor        2011-01-08
#
# ...

# %%
#7 Put all the previously mentioned data transformations into a function.

# %%
list(map(lambda x: x.lower(),file1.columns))
# Out:
# ['customer',
#  'customer lifetime value',
#  'coverage',
#  'education',
#  'effective to date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location code',
#  'marital status',
#  'monthly premium auto',
#  'months since policy inception',
#  'number of policies',
#  'policy type',
#  'policy',
#  'renew offer type',
#  'sales channel',
#  'total claim amount',
#  'month']

# %%
#Search the NaN values
nanvalues = filter(lambda n :n.isna, file1)

# %% [markdown]
# #  Lab | Customer Analysis Round 3

# %%
#Show DataFrame info.
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   customer lifetime value        10910 non-null  float64
#  2   coverage                       10910 non-null  object
#  3   education                      10910 non-null  object
#  4   effective to date              10910 non-null  datetime64[ns]
#  5   employmentstatus               10910 non-null  object
#  6   gender                         10910 non-null  object
#  7   income                         10910 non-null  int64
#  8   location code                  10910 non-null  object
#  9   marital status                 10910 non-null  object
#  10  monthly premium auto           10910 non-null  int64
#  11  months since policy inception  10910 non-null  int64
# ...

# %%
#Describe DataFrame.
file1.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count             10910.000000  10910.000000          10910.000000
# mean               8018.241094  37536.284785             93.196059
# std                6885.081434  30359.195670             34.442532
# min                1898.007675      0.000000             61.000000
# 25%                4014.453113      0.000000             68.000000
# 50%                5771.147235  33813.500000             83.000000
# 75%                8992.779137  62250.750000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months since policy inception  number of policies  total claim amount  \
# count                   10910.000000        10910.000000        10910.000000
# mean                       48.091934            2.979193          434.888330
# std                        27.940675            2.399359          292.180556
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Out:
#       customer  customer lifetime value  coverage education effective to date  \
# 0      DK49336              4809.216960     Basic   College        2011-02-18
# 1      KX64629              2228.525238     Basic   College        2011-01-18
# 2      LZ68649             14947.917300     Basic  Bachelor        2011-02-10
# 3      XL78013             22332.439460  Extended   College        2011-01-11
# 4      QA50777              9025.067525   Premium  Bachelor        2011-01-17
# ...        ...                      ...       ...       ...               ...
# 10905  FE99816             15563.369440   Premium  Bachelor        2011-01-19
# 10906  KX53892              5259.444853     Basic   College        2011-01-06
# 10907  TL39050             23893.304100  Extended  Bachelor        2011-02-06
# 10908  WA60547             11971.977650   Premium   College        2011-02-13
# 10909  IV32877              6857.519928     Basic  Bachelor        2011-01-08
#
# ...
