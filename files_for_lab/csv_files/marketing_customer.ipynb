# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv('marketing_customer_analysis.csv')

# %%
file.shape
# Out:
# (10910, 26)

# %%
file.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
file.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
file = file.rename(columns={'EmploymentStatus' : 'Employment Status','Unnamed: 0' : 'Order' })

# %%
file.columns
# Out:
# Index(['Order', 'Customer', 'State', 'Customer Lifetime Value', 'Response',
#        'Coverage', 'Education', 'Effective To Date', 'Employment Status',
#        'Gender', 'Income', 'Location Code', 'Marital Status',
#        'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
file._get_numeric_data()
# Out:
#        Order  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0          0              4809.216960   48029                    61
# 1          1              2228.525238       0                    64
# 2          2             14947.917300   22139                   100
# 3          3             22332.439460   49078                    97
# 4          4              9025.067525   23675                   117
# ...      ...                      ...     ...                   ...
# 10905  10905             15563.369440       0                   253
# 10906  10906              5259.444853   61146                    65
# 10907  10907             23893.304100   39837                   201
# 10908  10908             11971.977650   64195                   158
# 10909  10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# ...

# %%
file.select_dtypes('object')
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       Employment Status Gender Location Code Marital Status     Policy Type  \
# ...

# %%
nulls_df = pd.DataFrame(file.isna().sum())

# %%
nulls_df
# Out:
#                                   0
# Order                             0
# Customer                          0
# State                           631
# Customer Lifetime Value           0
# Response                        631
# Coverage                          0
# Education                         0
# Effective To Date                 0
# Employment Status                 0
# Gender                            0
# Income                            0
# Location Code                     0
# Marital Status                    0
# Monthly Premium Auto              0
# Months Since Last Claim         633
# Months Since Policy Inception     0
# Number of Open Complaints       633
# Number of Policies                0
# Policy Type                       0
# Policy                            0
# Renew Offer Type                  0
# Sales Channel                     0
# Total Claim Amount                0
# Vehicle Class                   622
# Vehicle Size                    622
# ...

# %%
file = file.drop(['Vehicle Type'],axis=1)

# %%
file.columns
# Out:
# Index(['Order', 'Customer', 'State', 'Customer Lifetime Value', 'Response',
#        'Coverage', 'Education', 'Effective To Date', 'Employment Status',
#        'Gender', 'Income', 'Location Code', 'Marital Status',
#        'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
mean_median_claim = np.mean(file['Months Since Last Claim'])

# %%
file['Months Since Last Claim'] = file['Months Since Last Claim'].fillna(mean_median_claim)

# %%
file['Months Since Last Claim'].isna().value_counts()
# Out:
# False    10910
# Name: Months Since Last Claim, dtype: int64

# %%
mean_median_complaints = np.mean(file['Number of Open Complaints'])

# %%
file['Number of Open Complaints'] = file['Number of Open Complaints'].fillna(mean_median_complaints)

# %%
file['Number of Open Complaints'].isna().value_counts()
# Out:
# False    10910
# Name: Number of Open Complaints, dtype: int64

# %%
file['State'] = file['State'].fillna('Unknown')

# %%
file['Response'] = file['Response'].fillna('Unknown')

# %%
file['Vehicle Class'] = file['Vehicle Class'].fillna('Unknown')

# %%
file['Vehicle Size'] = file['Vehicle Size'].fillna('Unknown')

# %%
nulls_df = pd.DataFrame(file.isna().sum())

# %%
nulls_df
# Out:
#                                0
# Order                          0
# Customer                       0
# State                          0
# Customer Lifetime Value        0
# Response                       0
# Coverage                       0
# Education                      0
# Effective To Date              0
# Employment Status              0
# Gender                         0
# Income                         0
# Location Code                  0
# Marital Status                 0
# Monthly Premium Auto           0
# Months Since Last Claim        0
# Months Since Policy Inception  0
# Number of Open Complaints      0
# Number of Policies             0
# Policy Type                    0
# Policy                         0
# Renew Offer Type               0
# Sales Channel                  0
# Total Claim Amount             0
# Vehicle Class                  0
# Vehicle Size                   0
# Vehicle Class\t                0

# %%
import time

# %%
file['Effective To Date'] = pd.to_datetime(file['Effective To Date'], errors='coerce')

# %%
file.dtypes
# Out:
# Order                                     int64
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# Employment Status                        object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                 float64
# Months Since Policy Inception             int64
# Number of Open Complaints               float64
# Number of Policies                        int64
# Policy Type                              object
# Policy                                   object
# ...

# %%
file['Month'] = pd.DatetimeIndex(file['Effective To Date']).month

# %%
file.columns
# Out:
# Index(['Order', 'Customer', 'State', 'Customer Lifetime Value', 'Response',
#        'Coverage', 'Education', 'Effective To Date', 'Employment Status',
#        'Gender', 'Income', 'Location Code', 'Marital Status',
#        'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Class\t', 'Month'],
#       dtype='object')

# %%
file
# Out:
#        Order Customer    State  Customer Lifetime Value Response  Coverage  \
# 0          0  DK49336       No              4809.216960       No     Basic
# 1          1  KX64629       No              2228.525238       No     Basic
# 2          2  LZ68649       No             14947.917300       No     Basic
# 3          3  XL78013      Yes             22332.439460      Yes  Extended
# 4          4  QA50777       No              9025.067525       No   Premium
# ...      ...      ...      ...                      ...      ...       ...
# 10905  10905  FE99816       No             15563.369440       No   Premium
# 10906  10906  KX53892       No              5259.444853       No     Basic
# 10907  10907  TL39050       No             23893.304100       No  Extended
# 10908  10908  WA60547       No             11971.977650       No   Premium
# 10909  10909  IV32877  Unknown              6857.519928  Unknown     Basic
#
#       Education Effective To Date Employment Status Gender  ...  \
# ...

# %%
import datetime 
file_first_quarter = file[(file.Month == 1) | (file.Month == 2) | (file.Month == 3)]

# %%
file_first_quarter
# Out:
#        Order Customer    State  Customer Lifetime Value Response  Coverage  \
# 0          0  DK49336       No              4809.216960       No     Basic
# 1          1  KX64629       No              2228.525238       No     Basic
# 2          2  LZ68649       No             14947.917300       No     Basic
# 3          3  XL78013      Yes             22332.439460      Yes  Extended
# 4          4  QA50777       No              9025.067525       No   Premium
# ...      ...      ...      ...                      ...      ...       ...
# 10905  10905  FE99816       No             15563.369440       No   Premium
# 10906  10906  KX53892       No              5259.444853       No     Basic
# 10907  10907  TL39050       No             23893.304100       No  Extended
# 10908  10908  WA60547       No             11971.977650       No   Premium
# 10909  10909  IV32877  Unknown              6857.519928  Unknown     Basic
#
#       Education Effective To Date Employment Status Gender  ...  \
# ...

# %%
file.to_csv("filtered.csv")
