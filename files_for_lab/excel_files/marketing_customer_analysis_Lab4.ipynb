# %%
import pandas as pd
import numpy as np

analyses01 = pd.read_excel('marketing_customer_analysis.xlsx')

# %%
analyses01
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
analyses01.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
analyses02 = pd.read_excel('marketing_customer_analysis.xlsx',  index_col=0)
analyses02
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
analyses02.shape
# Out:
# (10910, 25)

# %%
cols = []
for column in range(len(analyses02.columns)):
    cols.append(analyses02.columns[column].upper()) #apend the lower function to the cols
analyses02.columns =  cols

# %%
analyses02
# Out:
#       CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  COVERAGE  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS GENDER  INCOME  ...  \
# ...

# %%
analyses02.select_dtypes("object")
# Out:
#       CUSTOMER       STATE RESPONSE  COVERAGE EDUCATION EMPLOYMENTSTATUS  \
# 0      DK49336     Arizona       No     Basic   College         Employed
# 1      KX64629  California       No     Basic   College       Unemployed
# 2      LZ68649  Washington       No     Basic  Bachelor         Employed
# 3      XL78013      Oregon      Yes  Extended   College         Employed
# 4      QA50777      Oregon       No   Premium  Bachelor    Medical Leave
# ...        ...         ...      ...       ...       ...              ...
# 10905  FE99816      Nevada       No   Premium  Bachelor       Unemployed
# 10906  KX53892      Oregon       No     Basic   College         Employed
# 10907  TL39050     Arizona       No  Extended  Bachelor         Employed
# 10908  WA60547  California       No   Premium   College         Employed
# 10909  IV32877         NaN      NaN     Basic  Bachelor       Unemployed
#
#       GENDER LOCATION CODE MARITAL STATUS     POLICY TYPE        POLICY  \
# ...

# %%
analyses02._get_numeric_data()
# Out:
#        CUSTOMER LIFETIME VALUE  INCOME  MONTHLY PREMIUM AUTO  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        MONTHS SINCE LAST CLAIM  MONTHS SINCE POLICY INCEPTION  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
analyses02.isna().sum()
# Out:
# CUSTOMER                            0
# STATE                             631
# CUSTOMER LIFETIME VALUE             0
# RESPONSE                          631
# COVERAGE                            0
# EDUCATION                           0
# EFFECTIVE TO DATE                   0
# EMPLOYMENTSTATUS                    0
# GENDER                              0
# INCOME                              0
# LOCATION CODE                       0
# MARITAL STATUS                      0
# MONTHLY PREMIUM AUTO                0
# MONTHS SINCE LAST CLAIM           633
# MONTHS SINCE POLICY INCEPTION       0
# NUMBER OF OPEN COMPLAINTS         633
# NUMBER OF POLICIES                  0
# POLICY TYPE                         0
# POLICY                              0
# RENEW OFFER TYPE                    0
# SALES CHANNEL                       0
# TOTAL CLAIM AMOUNT                  0
# VEHICLE CLASS                     622
# VEHICLE SIZE                      622
# VEHICLE TYPE                     5482
# ...

# %%
analyses02.isna().sum()/len(analyses02)*100
# Out:
# CUSTOMER                          0.000000
# STATE                             5.783685
# CUSTOMER LIFETIME VALUE           0.000000
# RESPONSE                          5.783685
# COVERAGE                          0.000000
# EDUCATION                         0.000000
# EFFECTIVE TO DATE                 0.000000
# EMPLOYMENTSTATUS                  0.000000
# GENDER                            0.000000
# INCOME                            0.000000
# LOCATION CODE                     0.000000
# MARITAL STATUS                    0.000000
# MONTHLY PREMIUM AUTO              0.000000
# MONTHS SINCE LAST CLAIM           5.802016
# MONTHS SINCE POLICY INCEPTION     0.000000
# NUMBER OF OPEN COMPLAINTS         5.802016
# NUMBER OF POLICIES                0.000000
# POLICY TYPE                       0.000000
# POLICY                            0.000000
# RENEW OFFER TYPE                  0.000000
# SALES CHANNEL                     0.000000
# TOTAL CLAIM AMOUNT                0.000000
# ...

# %%
nulls_df = pd.DataFrame(analyses02.isna().sum()/len(analyses02)).reset_index()
nulls_df.columns = ['column_name','percent_nulls']

# %%
nulls_df['percent_nulls'] >= 0.5
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# Name: percent_nulls, dtype: bool

# %%
nulls_df[nulls_df['percent_nulls'] >= 0.5]['column_name']
# Out:
# 24    VEHICLE TYPE
# Name: column_name, dtype: object

# %%
columns_to_drop = nulls_df[nulls_df['percent_nulls'] >= 0.5]['column_name'].values

# %%
columns_to_drop
# Out:
# array(['VEHICLE TYPE'], dtype=object)

# %%
analyses02.drop(columns_to_drop,axis=1,inplace=True)

# %%
analyses02
# Out:
#       CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  COVERAGE  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS GENDER  INCOME  ...  \
# ...

# %%
analyses02.isna().sum()/len(analyses02)*100
# Out:
# CUSTOMER                         0.000000
# STATE                            5.783685
# CUSTOMER LIFETIME VALUE          0.000000
# RESPONSE                         5.783685
# COVERAGE                         0.000000
# EDUCATION                        0.000000
# EFFECTIVE TO DATE                0.000000
# EMPLOYMENTSTATUS                 0.000000
# GENDER                           0.000000
# INCOME                           0.000000
# LOCATION CODE                    0.000000
# MARITAL STATUS                   0.000000
# MONTHLY PREMIUM AUTO             0.000000
# MONTHS SINCE LAST CLAIM          5.802016
# MONTHS SINCE POLICY INCEPTION    0.000000
# NUMBER OF OPEN COMPLAINTS        5.802016
# NUMBER OF POLICIES               0.000000
# POLICY TYPE                      0.000000
# POLICY                           0.000000
# RENEW OFFER TYPE                 0.000000
# SALES CHANNEL                    0.000000
# TOTAL CLAIM AMOUNT               0.000000
# ...

# %%
#substituir o valor null pela media da coluna
#transformar as colunas em numero

# %%
rows_to_drop = nulls_df[nulls_df['percent_nulls'] >= 0.05]['column_name']

# %%
rows_to_drop
# Out:
# 1                         STATE
# 3                      RESPONSE
# 13      MONTHS SINCE LAST CLAIM
# 15    NUMBER OF OPEN COMPLAINTS
# 22                VEHICLE CLASS
# 23                 VEHICLE SIZE
# 24                 VEHICLE TYPE
# Name: column_name, dtype: object

# %%
analyses02
# Out:
#       CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  COVERAGE  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS GENDER  INCOME  ...  \
# ...

# %%
dropnull = analyses02.dropna(subset=['STATE', 'RESPONSE','MONTHS SINCE LAST CLAIM','NUMBER OF OPEN COMPLAINTS','VEHICLE CLASS','VEHICLE SIZE']) #remove null values from the cell

# %%
dropnull.isna().sum()/len(dropnull)*100
# Out:
# CUSTOMER                         0.0
# STATE                            0.0
# CUSTOMER LIFETIME VALUE          0.0
# RESPONSE                         0.0
# COVERAGE                         0.0
# EDUCATION                        0.0
# EFFECTIVE TO DATE                0.0
# EMPLOYMENTSTATUS                 0.0
# GENDER                           0.0
# INCOME                           0.0
# LOCATION CODE                    0.0
# MARITAL STATUS                   0.0
# MONTHLY PREMIUM AUTO             0.0
# MONTHS SINCE LAST CLAIM          0.0
# MONTHS SINCE POLICY INCEPTION    0.0
# NUMBER OF OPEN COMPLAINTS        0.0
# NUMBER OF POLICIES               0.0
# POLICY TYPE                      0.0
# POLICY                           0.0
# RENEW OFFER TYPE                 0.0
# SALES CHANNEL                    0.0
# TOTAL CLAIM AMOUNT               0.0
# VEHICLE CLASS                    0.0
# VEHICLE SIZE                     0.0
# dtype: float64

# %%
dtalab4 = dropnull
dtalab4
# Out:
#       CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  COVERAGE  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS GENDER  INCOME  \
# ...

# %%
dtalab4['MONTH'] = dtalab4['EFFECTIVE TO DATE'].apply(lambda x: str(x)[5:7])
dtalab4
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_16660\1671647778.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtalab4['MONTH'] = dtalab4['EFFECTIVE TO DATE'].apply(lambda x: str(x)[5:7])
#       CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  COVERAGE  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# ...

# %%
dtalab4=dtalab4[['CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE', 'RESPONSE', 'COVERAGE',
       'EDUCATION', 'EFFECTIVE TO DATE', 'MONTH','EMPLOYMENTSTATUS', 'GENDER',
       'INCOME', 'LOCATION CODE', 'MARITAL STATUS', 'MONTHLY PREMIUM AUTO',
       'MONTHS SINCE LAST CLAIM', 'MONTHS SINCE POLICY INCEPTION',
       'NUMBER OF OPEN COMPLAINTS', 'NUMBER OF POLICIES', 'POLICY TYPE',
       'POLICY', 'RENEW OFFER TYPE', 'SALES CHANNEL', 'TOTAL CLAIM AMOUNT',
       'VEHICLE CLASS', 'VEHICLE SIZE']]
dtalab4
# Out:
#       CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE  COVERAGE  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   EDUCATION EFFECTIVE TO DATE MONTH EMPLOYMENTSTATUS GENDER  \
# ...

# %%
dtalab4.to_csv('dtalab4.csv')
